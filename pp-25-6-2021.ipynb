# %% [markdown]
# # Libs

# %%
# Recieving Data from Spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # API

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="",
                                                           client_secret=""))

# %% [markdown]
# # Explore

# %%
show = sp.search(q='پادکست', type='show', market='US', offset=0, limit=50)
#show['shows']['items'][0]

# %% [markdown]
# # Prepare

# %%
names = []
description = []
publisher = []
total_episodes = []
external_urls = []
for i in range(20):
    show = sp.search(q='پادکست', type='show', market='US', offset=i*50, limit=50)
    show = show['shows']['items']
    for e in show:
        names.append(e['name'])
        description.append(e['description'])
        publisher.append(e['publisher'])
        total_episodes.append(e['total_episodes'])
        external_urls.append(e['external_urls']['spotify'])

# %%
names = pd.Series(names)
description = pd.Series(description)
publisher = pd.Series(publisher)
total_episodes = pd.Series(total_episodes)
external_urls = pd.Series(external_urls)

# %%
df = pd.DataFrame(
{
    'Name': names,
    'Publisher': publisher,
    'Description': description,
    'Total Episodes': total_episodes,
    'URL': external_urls,
    
})

df.index += 1

# %% [markdown]
# # Finally!

# %%
df
# Out:
#                                            Name             Publisher  \
# 1                         ChannelB پادکست فارسی           Ali Bandari
# 2     Masty o Rasty | پادکست فارسی مستی و راستی             King Raam
# 3                                     پادکست رخ          Rokh Podcast
# 4                 Radio Deev / پادکست رادیو دیو             RadioDeev
# 5                   پادکست کتاب کست - KetabCast  کتاب کست - KetabCast
# ...                                         ...                   ...
# 996                          سگ مست | Sagmast                 matinus
# 997                            داستان های کوتاه          Farzad Bayan
# 998                       NightPods - نایت پادز       NoN Residential
# 999       🔺ایلومیناتی: فرقه‌ای که زمین را بلعید                  1343
# 1000                                  سولاریس 💫       Hesam Bokazadeh
#
#                                             Description  Total Episodes  \
# 1     در هر اپیزود پادکست فارسی چنل‌بی گزارش یک ماجر...              83
# 2     Welcome to Masty o Rasty "The Drunken Truth" p...             142
# 3      داستان زندگی کسانی که قسمتی از تاریخ را رقم زدند              22
# 4     پادکست فارسی رادیو دیو مجله ی شنیداری فرهنگی ه...              32
# 5     📚کتاب کست - Ketab Cast ، پادکست کتاب های صوتی ...             534
# ...                                                 ...             ...
# 996   sagmast by Matinus alkohol lovers سگ مست پادکس...              11
# 997                                      توی این پادکست               1
# 998   نایت‌پادز یک پادکست سرگرمی است که در آن دور هم...               5
# 999   در این پادکست درباره‌ی فرقه‌ای خواهید شنید که ...               2
# 1000  اگه شما هم با شنیدن اسم آسیموف نیشتون باز میشه...               9
#
#                                                     URL
# 1     https://open.spotify.com/show/2PmMxFZ4OIW5DoUY...
# 2     https://open.spotify.com/show/35RtCrgybsUG3dos...
# 3     https://open.spotify.com/show/0hDXe6EN56UZsPBr...
# 4     https://open.spotify.com/show/1KZXcjPkHVeaziGY...
# 5     https://open.spotify.com/show/1eoeo5t8CfjoucLo...
# ...                                                 ...
# 996   https://open.spotify.com/show/3nEp3Tpo8QLnhVZs...
# 997   https://open.spotify.com/show/5WRbEroh1Wzb5bvW...
# 998   https://open.spotify.com/show/1o2Kvl0Q0rrOCVEZ...
# 999   https://open.spotify.com/show/5ZAb7t3FF1A7eKrD...
# 1000  https://open.spotify.com/show/0IOjqr6qtaaFw9B4...
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Top 20

# %%
df[:20]
# Out:
#                                                  Name               Publisher  \
# 1                               ChannelB پادکست فارسی             Ali Bandari
# 2           Masty o Rasty | پادکست فارسی مستی و راستی               King Raam
# 3                                           پادکست رخ            Rokh Podcast
# 4                       Radio Deev / پادکست رادیو دیو               RadioDeev
# 5                         پادکست کتاب کست - KetabCast    کتاب کست - KetabCast
# 6                                        پادکست آرامش      arameshpodcast.com
# 7              ‌BPLUS بی‌پلاس پادکست فارسی خلاصه کتاب             Ali Bandari
# 8                             Digesttt/ پادکست دایجست            فرشاد محمودی
# 9                             پادکست جنایی آخرین شاهد          Mahdi Pourbaqi
# 10                                پادکست مختصر و مفید         Ardeshir Tayebi
# 11                meditation podcast | مدیتیشن پادکست      meditation podcast
# 12                               On podcast پادکست آن                  mersen
# 13                               owrsi | پادکست اورسی         Saman Karampour
# 14  پادکست فارسی ناوکست / Navcast/ترجمهٔ مستقل کتا...            Roshan Abady
# 15                                         پادکست بوم            Mehdi Abbasi
# 16                Moniaz Podcast | پادکست فارسی منیاز                  moniaz
# 17                            R.O.Tik | پادکست اروتیک                   R.O.✔
# 18                Saate Sefr | پادکست فارسی ساعت صفر   Amin Matin | امین متین
# 19                           Ravi | پادکست فارسی راوی           arash kaviani
# 20                  پادکست – جادی دات نت | کیبرد آزاد                    Jadi
#
#                                           Description  Total Episodes  \
# 1   در هر اپیزود پادکست فارسی چنل‌بی گزارش یک ماجر...              83
# 2   Welcome to Masty o Rasty "The Drunken Truth" p...             142
# 3    داستان زندگی کسانی که قسمتی از تاریخ را رقم زدند              22
# 4   پادکست فارسی رادیو دیو مجله ی شنیداری فرهنگی ه...              32
# 5   📚کتاب کست - Ketab Cast ، پادکست کتاب های صوتی ...             534
# 6   هدف پادکست آرامش، هدیه کردن دقایقی آرامش و احس...              29
# 7                    خلاصه‌ی فارسی کتابهای غیرداستانی              63
# 8   پادکست دایجست مسائل نسبتاً پیچیده دنیای اطراف ...              41
# 9   این یک پادکست قصه گو نیست پرونده های جنایی واق...              79
# 10      کنج‌کاوی در تاریخ، سیاست و علم با اردشیر طیبی              50
# 11  در هر اپیزود مدیتیشن پادکست، مدیتیشنی برای کمک...              58
# 12  در هر اپیزود پادکست آن، داستان واقعی آدمها رو ...              20
# 13                           غیر سطحی ببینیم و بشنویم              11
# 14  قسمتهای این فصل از ناوکست به صورت پیوسته به تر...              74
# 15                           پادکست فارسی تاریخ فلسفه              34
# 16  پادکست منیاز با هدف آگاهی بخشی در جهت ایجاد زن...              47
# 17  🔞تنها پادکست اروتیک ایرونی!🍑🍆نود یا صداس سکستو...               7
# 18  ساعت صفر روایتی است از معمای زمان | *توجه : شا...              39
# 19  ما روایت گر قصه زندگی افرادی هستیم که یک چالشی...              23
# 20                             در دفاع از آزادی کیبرد              20
#
#                                                   URL
# 1   https://open.spotify.com/show/2PmMxFZ4OIW5DoUY...
# 2   https://open.spotify.com/show/35RtCrgybsUG3dos...
# 3   https://open.spotify.com/show/0hDXe6EN56UZsPBr...
# 4   https://open.spotify.com/show/1KZXcjPkHVeaziGY...
# 5   https://open.spotify.com/show/1eoeo5t8CfjoucLo...
# 6   https://open.spotify.com/show/7cr35mqkp0UbVPCn...
# 7   https://open.spotify.com/show/5HqY5kOdUaGvmQsW...
# 8   https://open.spotify.com/show/0APHFnyp6hB6de0s...
# 9   https://open.spotify.com/show/5oJxOMLttosMDiPu...
# 10  https://open.spotify.com/show/7bCiopnv1MlEl2UE...
# 11  https://open.spotify.com/show/2KqzlJNguHFSjx73...
# 12  https://open.spotify.com/show/18dEbxRMhmCOSBLB...
# 13  https://open.spotify.com/show/5G5S9nV9WaMVbsJh...
# 14  https://open.spotify.com/show/2r3S4hgcs0ksj5V9...
# 15  https://open.spotify.com/show/3a6TjdLquDQvSXtV...
# 16  https://open.spotify.com/show/2pCF0JIZOagq3OJS...
# 17  https://open.spotify.com/show/7gFfKTEEE0ILmTLP...
# 18  https://open.spotify.com/show/6ZbOqYS6h8Q4e2h2...
# 19  https://open.spotify.com/show/6YpWbAA0PL9A3jEF...
# 20  https://open.spotify.com/show/2la9aW3sYTNjxVaa...

# %% [markdown]
# ## Shows containing word 'مدیتیشن'

# %%
slice = df[df['Description'].str.contains('مدیتیشن')]
slice
# Out:
#                                                   Name             Publisher  \
# 6                                         پادکست آرامش    arameshpodcast.com
# 11                 meditation podcast | مدیتیشن پادکست    meditation podcast
# 38   پادکست مدیتیشن فارسی دارما | Dharma Meditation...           Ali Delshad
# 108  پادکست مدیتیشن فارسی دارما | Dharma Meditation...           Ali Delshad
# 165  پادکست انگیزشی و ژرف‌اندیشی دارما موتیویشن | D...           Ali Delshad
# 192                                        آرام پادکست     محمد مقامیان زاده
# 339  پادکست روانشناسی و پزشکی دارما کلینیک | Dharma...           Ali Delshad
# 783               YogaLifeRomane یوگا و زندگی با رمانه  Romaneh Khalili Pour
# 870                                    Asoothe | آسوده        Araz Pourvatan
# 947                                             RAZPAD           راضیه رضایی
#
#                                            Description  Total Episodes  \
# 6    هدف پادکست آرامش، هدیه کردن دقایقی آرامش و احس...              29
# 11   در هر اپیزود مدیتیشن پادکست، مدیتیشنی برای کمک...              58
# 38   مراقبه یا مدیتیشن از طریق ورود به بخش نیمه خود...             100
# 108  من علی هستم و پادکست دارما رو با کمک هلیا برات...              14
# 165  در پادکست دارما موتیویشن، سعی می کنیم با کارآف...               6
# 192  آرام پادکست کانالی با محتوای انگیزشی واجتماعی ...               7
# 339  دارما‌ کلینیک پادکستیه که در مورد مسائل روانشن...              19
# 783  سلام من رمانه خلیلی پور هستم مربی یوگا  در هر ...              14
# 870  Life is an experiment. Here the experience is ...               3
# 947  سلام. من اینجا هستم با هدف قرار دادن مهربانی و...               9
#
#                                                    URL
# 6    https://open.spotify.com/show/7cr35mqkp0UbVPCn...
# 11   https://open.spotify.com/show/2KqzlJNguHFSjx73...
# 38   https://open.spotify.com/show/0VcAShPf0PhYeE1w...
# 108  https://open.spotify.com/show/5mLXV3uB5GX6ZHct...
# 165  https://open.spotify.com/show/0aslEbqmSj69VDRE...
# 192  https://open.spotify.com/show/6ZKqF9FLQyo4ZurD...
# 339  https://open.spotify.com/show/2ptVB562q1m0hBo4...
# 783  https://open.spotify.com/show/0fu00jdnh2Cn3pS8...
# 870  https://open.spotify.com/show/2HGdWKcdo6Sj32wn...
# 947  https://open.spotify.com/show/6HiN7mGLCz7D1A8c...

# %% [markdown]
# ## Statistics

# %%
df.describe()
# Out:
#        Total Episodes
# count     1000.000000
# mean        27.484000
# std         75.644338
# min          0.000000
# 25%          4.000000
# 50%         10.000000
# 75%         25.000000
# max       1283.000000

# %%
df['Total Episodes'].value_counts()
# Out:
# 1      105
# 2       69
# 4       57
# 3       55
# 5       52
#       ...
# 114      1
# 115      1
# 116      1
# 136      1
# 0        1
# Name: Total Episodes, Length: 126, dtype: int64

# %% [markdown]
# ## With more than 400 Episodes

# %%
df[df['Total Episodes'] > 400]
# Out:
#                                 Name                       Publisher  \
# 5        پادکست کتاب کست - KetabCast            کتاب کست - KetabCast
# 54   Radio Padio | پادکست خبری پادیو  RadioPadio | پادکست خبری پادیو
# 469                  روانشناسی شخصیت     اساتید روانشناسی دانشگاه‌ها
# 493       روانشناسی شخصیت‌ و خوشبختی                           Plato
# 550         تلویزیون میهن | mihantv                         mihantv1
# 939                          داستانک                    سعید امینیان
#
#                                            Description  Total Episodes  \
# 5    📚کتاب کست - Ketab Cast ، پادکست کتاب های صوتی ...             534
# 54   نمیذاریم بی‌خبر بمونین! پادکست خبری رادیو پادی...             529
# 469  دکتر فرهنگ هلاکویی دکتر محمدرضا سرگلزایی دکتر ...             833
# 493  همه مکالمات دکتر هلاکویی در فصل 1 قرار دارند. ...            1073
# 550  با ما از پشت پرده ی سیاست با خبر شوید و از بهت...            1283
# 939  در اپیزودهای جدید، من برداشت خودم را از داستان...             430
#
#                                                    URL
# 5    https://open.spotify.com/show/1eoeo5t8CfjoucLo...
# 54   https://open.spotify.com/show/47ITpNV6wVBmF0Hw...
# 469  https://open.spotify.com/show/7FiQjYyDfZtZHFbU...
# 493  https://open.spotify.com/show/5r5dc2JA7Y56ZYFd...
# 550  https://open.spotify.com/show/7cPVgVgTb2PAnysU...
# 939  https://open.spotify.com/show/3BjE3M4G87Yri4Ot...

# %%
df[df['Total Episodes'] < 10]
# Out:
#                                        Name        Publisher  \
# 17                  R.O.Tik | پادکست اروتیک            R.O.✔
# 42     وقت خواب | پادکستی برای رفع بی خوابی    لویی و دوستان
# 59                پادکست هُشْتَکْ | Hoshtak    MohammadSalar
# 61                       Mind Master پادکست             Sara
# 68        salam podcast | پادکست فارسی سلام          basalam
# ...                                     ...              ...
# 995                 سبکتو | Sabketo (فارسی)          Sabketo
# 997                        داستان های کوتاه     Farzad Bayan
# 998                   NightPods - نایت پادز  NoN Residential
# 999   🔺ایلومیناتی: فرقه‌ای که زمین را بلعید             1343
# 1000                              سولاریس 💫  Hesam Bokazadeh
#
#                                             Description  Total Episodes  \
# 17    🔞تنها پادکست اروتیک ایرونی!🍑🍆نود یا صداس سکستو...               7
# 42    وقت خواب ، یک پادکست فارسی زبانه که برای مواقع...               5
# 59    پادکست هشتک رو می شنوید من، محمد سالار نعمتی ه...               8
# 61    مایند مستر یه پادکست فارسیه که توش جنبه‌های مخ...               8
# 68        قصه‌ی محصولات و دست‌ساخته‌ها از زبان سازندگان               8
# ...                                                 ...             ...
# 995            در پادکست‌های سبکتو در کنار شنونده‌ها...               0
# 997                                      توی این پادکست               1
# 998   نایت‌پادز یک پادکست سرگرمی است که در آن دور هم...               5
# 999   در این پادکست درباره‌ی فرقه‌ای خواهید شنید که ...               2
# 1000  اگه شما هم با شنیدن اسم آسیموف نیشتون باز میشه...               9
#
#                                                     URL
# 17    https://open.spotify.com/show/7gFfKTEEE0ILmTLP...
# 42    https://open.spotify.com/show/5c27xgMZdXaSzAxb...
# 59    https://open.spotify.com/show/4Fhy3dfYAlkB5Nth...
# 61    https://open.spotify.com/show/5G2T1M7mSbcvY3d1...
# 68    https://open.spotify.com/show/7c7QY4VEU3MjDT9Q...
# ...                                                 ...
# 995   https://open.spotify.com/show/7wMHG6jwpMg4OWxF...
# 997   https://open.spotify.com/show/5WRbEroh1Wzb5bvW...
# 998   https://open.spotify.com/show/1o2Kvl0Q0rrOCVEZ...
# 999   https://open.spotify.com/show/5ZAb7t3FF1A7eKrD...
# 1000  https://open.spotify.com/show/0IOjqr6qtaaFw9B4...
#
# [486 rows x 5 columns]
